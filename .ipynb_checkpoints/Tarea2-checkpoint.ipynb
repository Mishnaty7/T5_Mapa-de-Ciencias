# %% [markdown]
# TAREA 2
#
# Mishelle Culcay
#
# Ejercicio 1
# Basado en las sesiones de Visualización de datos y Expresiones resulares. Realice una adaptación de la solución del MAP OF SCIENCE. Se requiere dos adaptaciones para resolver esta actividad:
#
# Buscar bibliografía de un tema de interés propio en la Página Web de PubMed,
# Realizar el minado de autores por país (en el ejemplo se encuentra realziado por las ciudades de USA).
# Para asignar las ubicación geográfica de los centroides de cada país (latitud y longitud), utilice la tabla Ubicación Geográfica de Países - Google Developer. Así como en la solución de referencia se señalan varias ciudades seleccionadas de USA.
# En su resolución señale/resalte a los siguientes países: USA, UK, Brazil, China, Australia, Norway.
# Cargue su cuaderno de Jupyter en GitHub, asegurandose de lo siguiente:
#
# En el documento se puede ver con claridad el Mapa de Ciencia de su tema de interés.
# La figura tiene etiquetas adecuadas en los ejes de la visualización.
# Se tiene al menos tres controles de la versión (3 commit con mensajes adecuados sobre la versión)

# %%
#Descargar librerias
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import math 
import seaborn as sns
import pandas as pd

# %%
import re
import csv

# %%
with open("pubmed-coloncance-set.txt", encoding= 'utf-8') as f:
    datos = f.read()

# %%
datos = re.sub(r'\n\s{6}', ' ', datos)
dat= re.findall (r"\,\s[A-zA-Z]{2,13}\.", datos)
print(dat)
# Out:
# [', Singapore.', ', Singapore.', ', Singapore.', ', Singapore.', ', Germany.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', China.', ', China.', ', China.', ', China.', ', China.', ', SAU.', ', SAU.', ', SAU.', ', SAU.', ', SAU.', ', SAU.', ', SAU.', ', Thailand.', ', Thailand.', ', Thailand.', ', No.', ', China.', ', No.', ', China.', ', No.', ', China.', ', No.', ', China.', ', No.', ', China.', ', No.', ', China.', ', No.', ', China.', ', No.', ', China.', ', China.', ', No.', ', China.', ', Belgium.', ', Brazil.', ', USA.', ', Belgium.', ', China.', ', USA.', ', China.', ', China.', ', USA.', ', China.', ', Lorca.', ', Sweden.', ', Sweden.', ', Sweden.', ', Sweden.', ', Sweden.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Germany.', ', Bangladesh.', ', Bangladesh.', ', Bangladesh.', ', Bangladesh.', ', USA.', ', Inc.', ', USA.', ', USA.', ', Greece.', ', Inc.', ', USA.', ', respectively.', ', USA.', ', Australia.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Ohio.', ', OH.', ', Louisiana.', ', China.', ', China.', ', China.', ', China.', ', China.', ', India.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', Italy.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', China.', ', USA.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Taiwan.', ', Deutschland.', ', Deutschland.', ', Deutschland.', ', Deutschland.', ', Deutschland.', ', respectively.', ', respectively.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Ukraine.', ', Basel.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', St.', ', Greece.', ', MA.', ', USA.', ', MPH.', ', Turkey.', ', Weinheim.', ', Bulgaria.', ', Finland.', ', Finland.', ', Bulgaria.', ', Russia.', ', Bulgaria.', ', Finland.', ', Finland.', ', Russia.', ', Russia.', ', UK.', ', UK.', ', USA.', ', Poland.', ', Poland.', ', Poland.', ', Poland.', ', Poland.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', NO.', ', China.', ', China.', ', China.', ', China.', ', China.', ', China.', ', respectively.', ', St.', ', USA.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', Japan.', ', respectively.', ', respectively.', ', respectively.', ', Turkey.', ', Turkey.', ', Turkey.', ', Turkey.', ', Turkey.' ...

# %%
zipcodes = re.findall (r"\,\s[A-zA-Z]{2,13}\.", datos)

# %%
len(zipcodes)
# Out:
# 6643

# %%
zipcodes[:20]
# Out:
# [', Singapore.',
#  ', Singapore.',
#  ', Singapore.',
#  ', Singapore.',
#  ', Germany.',
#  ', Italy.',
#  ', Italy.',
#  ', Italy.',
#  ', Italy.',
#  ', Italy.',
#  ', Italy.',
#  ', China.',
#  ', China.',
#  ', China.',
#  ', China.',
#  ', China.',
#  ', SAU.',
#  ', SAU.',
#  ', SAU.',
#  ', SAU.']

# %%
unique_zipcodes = list(set(zipcodes))

# %%
unique_zipcodes.sort()

# %%
unique_zipcodes[:20]
# Out:
# [', AL.',
#  ', AZ.',
#  ', Aichi.',
#  ', Argentina.',
#  ', Arizona.',
#  ', Aurora.',
#  ', Australia.',
#  ', Austria.',
#  ', Av.',
#  ', Aviano.',
#  ', Az.',
#  ', Baltimore.',
#  ', Bangladesh.',
#  ', Basel.',
#  ', Belgium.',
#  ', Biella.',
#  ', Boston.',
#  ', Brazil.',
#  ', Brazil].',
#  ', Bulgaria.']

# %%
len(unique_zipcodes)
# Out:
# 244

# %%
zip_coordinates = {}
with open('zipcodes_coordinates.txt') as f:
    csvr = csv.DictReader(f)
    for row in csvr:
        zip_coordinates[row['Name']] = [float(row['Latitude']), 
                                       float(row['Longitude'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12056/2346625333.py in <module>
#       3     csvr = csv.DictReader(f)
#       4     for row in csvr:
# ----> 5         zip_coordinates[row['Name']] = [float(row['Latitude']),
#       6                                        float(row['Longitude'])]
#
# ValueError: could not convert string to float: ''

# %%
zip_code = []
zip_long = []
zip_lat = []
zip_count = []

# %%
for z in unique_zipcodes:
    if z in zip_coordinates.keys():
        zip_code.append(z)
        zip_lat.append(zip_coordinates[z][0])
        zip_long.append(zip_coordinates[z][1])
        zip_count.append(zipcodes.count(z))
